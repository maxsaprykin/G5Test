# %%
from pandas import pandas as pd
df = pd.read_excel('data.xlsx')

# %%
df.groupby('publisher_sub_site.name').head()
# Out:
#        country_id  publisher_sub_publisher_id  publisher_sub_site_id  \
# 0             840                   170591870              559852022
# 1             784                   173648884             1789045691
# 2             643                   178789270             3437707919
# 3             124                   170690698              521853300
# 4             156                   171176670             1125634262
# 5             124                   265964579             4353049040
# 6             840                   218403816             2059240487
# 7             300                   313328015             3801576528
# 8               4                   170545110             1195709550
# 9             124                   306141809             4293914458
# 10            414                   170537284             1248170125
# 11            554                   235490501             1634463281
# 12            208                   220181356             1647083437
# ...
